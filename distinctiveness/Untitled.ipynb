# %%
# Import distinctiveness-R
if(!require('igraph')) {
  install.packages('igraph')
  library('igraph')
}
source("dc.R")

# %%
g <- make_empty_graph(directed = FALSE) %>%
  add_vertices(1, name = "A") %>%
  add_vertices(1, name = "B") %>%
  add_vertices(1, name = "C") %>%
  add_vertices(1, name = "D") %>%
  add_vertices(1, name = "E") %>%
  add_vertices(1, name = "F")
g <- g + edge(1, 5, weight = 5) + edge(1, 2, weight = 2) + 
     edge(2, 6, weight = 5) + edge(2, 3, weight = 2) + 
     edge(2, 4, weight = 2) + edge(3, 4, weight = 5)
plot(g, edge.width = E(g)$weight)
# Out:
# Plot with title ""

# %%
distinctiveness(g, normalize = TRUE)
# Out:
# Warning message in subgraph(G, 1:n):
# "At structural_properties.c:1984 :igraph_subgraph is deprecated from igraph 0.6, use igraph_induced_subgraph instead"
# $D1
# [1] 0.21109175 0.33663763 0.12495644 0.12495644 0.11386469 0.02772938
#
# $D2
# [1] 0.22772938 0.54159407 0.14159407 0.14159407 0.11386469 0.02772938
#
# $D3
# [1] 0.15477969 0.21067055 0.10388842 0.10388842 0.09014085 0.05089127
#
# $D4
# [1] 0.21454545 0.26857143 0.15740260 0.15740260 0.14285714 0.09090909
#
# $D5
# [1] 0.25 0.50 0.15 0.15 0.10 0.05
