# %%
pip install -U networkx

# %%
# Import distinctiveness
from distinctiveness.dc import distinctiveness

#Import Networkx and Pandas
import networkx as nx
import pandas as pd
import os as os
import matplotlib as plt
import scipy as sp

# %%
os.getcwd()
from distinctiveness.dc import distinctiveness

# %%
os.getcwd()
# os.chdir("distinctiveness-R/distinctiveness")
# Out:
# 'C:\\Users\\IV\\Desktop\\UniPG\\distinctiveness-R'

# %%
#Import Networkx and Pandas
import networkx as nx
import pandas as pd
import xml as xml

# %%
g = nx.read_pajek("resources/Undirected.net")
for line in nx.generate_edgelist(g):
    print(line)
# Out:
# v1 v3 {'weight': 1.0}
# v1 v3 {'weight': 1.0}
# v1 v3 {'weight': 1.0}
# v1 v3 {'weight': 1.0}
# v1 v3 {'weight': 1.0}
# v1 v3 {'weight': 1.0}
# v1 v10 {'weight': 1.0}
# v1 v10 {'weight': 1.0}
# v1 v7 {'weight': 1.0}
# v1 v16 {'weight': 1.0}
# v1 v35 {'weight': 1.0}
# v1 v23 {'weight': 1.0}
# v1 v23 {'weight': 1.0}
# v1 v67 {'weight': 1.0}
# v1 v107 {'weight': 1.0}
# v1 v42 {'weight': 1.0}
# v1 v138 {'weight': 1.0}
# v1 v61 {'weight': 1.0}
# v1 v166 {'weight': 1.0}
# v1 v36 {'weight': 1.0}
# v1 v105 {'weight': 1.0}
# v1 v186 {'weight': 1.0}
# v1 v280 {'weight': 1.0}
# v1 v6 {'weight': 1.0}
# v1 v382 {'weight': 1.0}
# v1 v191 {'weight': 1.0}
# v1 v379 {'weight': 1.0}
# v1 v264 {'weight': 1.0}
# v1 v474 {'weight': 1.0}
# v1 v464 {'weight': 1.0}
# v1 v450 {'weight': 1.0}
# v1 v71 {'weight': 1.0}
# v1 v509 {'weight': 1.0}
# v1 v86 {'weight': 1.0}
# v1 v2 {'weight': 1.0}
# v1 v329 {'weight': 1.0}
# v1 v643 {'weight': 1.0}
# v1 v797 {'weight': 1.0}
# v2 v3 {'weight': 1.0}
# ...

# %%
nx.draw(g)

# %%
for node in g.nodes(data=True):
    print(node)

# %%
DC = distinctiveness(g)
pd.options.display.max_rows = 1000
DC = pd.DataFrame(DC)
DC
import xlsxwriter as xw
DC.to_excel('resources/undir-Py.xlsx')
# Out:
# MultiGraph converted to Graph

# %%
g_dir = nx.read_pajek("resources/Directed.net")
DC = distinctiveness(g_dir)
pd.options.display.max_rows = 1000
DC = pd.DataFrame(DC)
DC
# Out:
# MultiDiGraph converted to DiGraph
#             D1_in      D2_in       D3_in       D4_in     D5_in      D1_out  \
# v1       7.521575   7.521575    8.631083    1.366667  1.366667   37.381557
# v2       7.919515   7.919515    9.029023    1.333333  1.333333   27.525038
# v3       4.743858   4.743858    5.483530    0.500000  0.500000    2.522444
# v4      10.742989  10.742989   12.222333    2.166667  2.166667   31.049472
# v5      10.089777  10.089777   11.569121    1.333333  1.333333    2.397505
# v6       7.919515   7.919515    9.029023    1.333333  1.333333    7.250508
# v7       2.999565   2.999565    3.369401    1.000000  1.000000   12.839465
# v8       2.698535   2.698535    3.068371    0.500000  0.500000    5.096041
# v9       2.698535   2.698535    3.068371    0.500000  0.500000    7.919515
# v10      4.919950   4.919950    5.659622    0.583333  0.583333    9.424231
# v11     12.390372  12.390372   14.239552    1.533333  1.533333    4.999131
# ...

# %%
import xlsxwriter as xw
DC.to_excel('resources/dir-Py.xlsx')
