# %%
# Import distinctiveness-R
if(!require('igraph')) {
    install.packages('igraph')
    library('igraph')
}
source("distinctiveness/dc.R")
# Out:
# Loading required package: igraph
# Warning message:
# "package 'igraph' was built under R version 3.6.3"
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union

# %%
# getwd()
g <- read_graph("resources/Undirected.net", format = "pajek")

# %%
plot(g, edge.width = E(g)$weight)
# Out:
# Plot with title ""

# %%
dc <- distinctiveness(g)
write_xlsx(dc, "resources/undir-R.xlsx")

# %%
# Import distinctiveness-R
if(!require('igraph')) {
    install.packages('igraph')
    library('igraph')
}
source("distinctiveness/dc.R")

# %%
g_dir <- read_graph("resources/Directed.net", format = "pajek")
dc <- distinctiveness(g_dir)
dc
# Out:
#      Node  D1_IN     D1_OUT    D2_IN     D2_OUT    D3_IN     D3_OUT
# 1    v1     7.521575 37.381557  7.521575 13.094737  8.631083 42.559260
# 2    v2     7.919515 27.525038  7.919515  4.823040  9.029023 31.593233
# 3    v3     4.743858  2.522444  4.743858  2.522444  5.483530  2.892280
# 4    v4    10.742989 31.049472 10.742989  9.471923 12.222333 35.857339
# 5    v5    10.089777  2.397505 10.089777  2.397505 11.569121  2.767341
# 6    v6     7.919515  7.250508  7.919515  7.250508  9.029023  8.360016
# 7    v7     2.999565 12.839465  2.999565 12.839465  3.369401 14.176761
# 8    v8     2.698535  5.096041  2.698535  5.096041  3.068371  5.835713
# 9    v9     2.698535  7.919515  2.698535  7.919515  3.068371  9.029023
# 10   v10    4.919950  9.424231  4.919950  9.424231  5.659622 10.903574
# 11   v11   12.390372  4.999131 12.390372  4.999131 14.239552  5.738803
# 12   v12    5.044888  5.522010  5.044888  5.522010  5.784560  6.261682
# ...

# %%
install.packages('writexl')
library('writexl')
# Out:
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# writexl  1.4.0  1.4.2              TRUE
#
#   Binaries will be installed
# package 'writexl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\IV\AppData\Local\Temp\Rtmp2vc5eR\downloaded_packages
# Warning message:
# "package 'writexl' was built under R version 3.6.3"

# %%
dc <- distinctiveness(g_dir)
write_xlsx(dc, "resources/dir-R.xlsx")
